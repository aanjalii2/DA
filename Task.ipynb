# %% [markdown]
# <a href="https://colab.research.google.com/github/aanjalii2/DA/blob/main/Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.Data Collection & Exploration**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1.1 Dataset Loading**

# %%
# Load Dataset
df = pd.read_csv("/content/drive/MyDrive/DA/AmesHousing.csv")

# %% [markdown]
# **1.2 Initial Exploration**

# %%
# Show the first five rows
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
 # Show the last five rows
df.tail()
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 2925   NaN       IR1          Lvl  ...         0     NaN  GdPrv          NaN
# 2926   NaN       IR1          Low  ...         0     NaN  MnPrv          NaN
# 2927   NaN       Reg          Lvl  ...         0     NaN  MnPrv         Shed
# 2928   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2929   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
#
# ...

# %%
 # Show the information of dataset in summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
 # Show the shape(rows and columns)
df.shape
# Out:
# (2930, 82)

# %%
 # Shows the summary
df.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %%
 # Shows all the names of columns
df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
#checking the missing values in dataset
df.isnull().sum()
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['Lot Frontage',
#  'Alley',
#  'Mas Vnr Type',
#  'Mas Vnr Area',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Electrical',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Fireplace Qu',
#  'Garage Type',
#  'Garage Yr Blt',
#  'Garage Finish',
#  'Garage Cars',
#  'Garage Area',
#  'Garage Qual',
#  'Garage Cond',
#  'Pool QC',
#  'Fence',
#  'Misc Feature']

# %%
#checking the duplicate rows
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2925    False
# 2926    False
# 2927    False
# 2928    False
# 2929    False
# Length: 2930, dtype: bool

# %%
#showing the number of dupicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
 # Show the unique values of all columns
df.nunique()
# Out:
# Order             2930
# PID               2930
# MS SubClass         16
# MS Zoning            7
# Lot Frontage       128
#                   ...
# Mo Sold             12
# Yr Sold              5
# Sale Type           10
# Sale Condition       6
# SalePrice         1032
# Length: 82, dtype: int64

# %% [markdown]
# **2. Data Cleaning and Transformation**

# %% [markdown]
# **Handle Missing Values:**

# %%
sns.histplot(df['Lot Frontage'], kde=True)
# Out:
# <Axes: xlabel='Lot Frontage', ylabel='Count'>

# %%
df['Lot Frontage']
# Out:
# 0       141.0
# 1        80.0
# 2        81.0
# 3        93.0
# 4        74.0
#         ...
# 2925     37.0
# 2926      NaN
# 2927     62.0
# 2928     77.0
# 2929     74.0
# Name: Lot Frontage, Length: 2930, dtype: float64

# %%
df['Lot Frontage'].isnull().sum()
# Out:
# np.int64(490)

# %%
df['Lot Frontage'].mean()
# Out:
# np.float64(69.22459016393442)

# %%
df['Lot Frontage'] = df['Lot Frontage'].fillna(df['Lot Frontage'].mean())

# %%
df['Lot Frontage']
# Out:
# 0       141.00000
# 1        80.00000
# 2        81.00000
# 3        93.00000
# 4        74.00000
#           ...
# 2925     37.00000
# 2926     69.22459
# 2927     62.00000
# 2928     77.00000
# 2929     74.00000
# Name: Lot Frontage, Length: 2930, dtype: float64

# %%
df['Lot Frontage'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Garage Area']
# Out:
# 0       528.0
# 1       730.0
# 2       312.0
# 3       522.0
# 4       482.0
#         ...
# 2925    588.0
# 2926    484.0
# 2927      0.0
# 2928    418.0
# 2929    650.0
# Name: Garage Area, Length: 2930, dtype: float64

# %%
df['Garage Area'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Garage Area'].median()
# Out:
# 480.0

# %%
df['Garage Area'] = df['Garage Area'].fillna(df['Garage Area'].median())

# %%
df['Electrical']
# Out:
# 0       SBrkr
# 1       SBrkr
# 2       SBrkr
# 3       SBrkr
# 4       SBrkr
#         ...
# 2925    SBrkr
# 2926    SBrkr
# 2927    SBrkr
# 2928    SBrkr
# 2929    SBrkr
# Name: Electrical, Length: 2930, dtype: object

# %%
df['Electrical'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2925    False
# 2926    False
# 2927    False
# 2928    False
# 2929    False
# Name: Electrical, Length: 2930, dtype: bool

# %%
df['Electrical'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Electrical'].mode()
# Out:
# 0    SBrkr
# Name: Electrical, dtype: object

# %%
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

# %%
df['Electrical'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Handling missing values by deleting the rows and column with missing values

# %%
df.isnull().sum()
# Out:
# Order             0
# PID               0
# MS SubClass       0
# MS Zoning         0
# Lot Frontage      0
#                  ..
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Sale Condition    0
# SalePrice         0
# Length: 82, dtype: int64

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['Alley',
#  'Mas Vnr Type',
#  'Mas Vnr Area',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Fireplace Qu',
#  'Garage Type',
#  'Garage Yr Blt',
#  'Garage Finish',
#  'Garage Cars',
#  'Garage Qual',
#  'Garage Cond',
#  'Pool QC',
#  'Fence',
#  'Misc Feature']

# %%
df.dropna(axis=1, inplace=True)

# %%
df.dropna(axis=1).shape
# Out:
# (2930, 58)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# []

# %% [markdown]
# Outlier Detection and Treatment

# %%
# Function to remove outliers based on IQR
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
# Apply outlier removal to selected important features
important_cols = ['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'SalePrice']

# %%
# Now proceed with outlier removal
important_cols =['SalePrice', 'Gr Liv Area', 'Lot Area', 'Order']

# %%
# Before removing outliers - Boxplots
for col in important_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f"Before Outlier Removal - {col}")
    plt.show()

# %%
# Remove outliers one column at a time
for col in important_cols:
    df = remove_outliers_iqr(df, col)

# %%
for col in important_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f"After Outlier Removal - {col}")
    plt.show()

# %% [markdown]
# Data Transformation:

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
label_encoder = LabelEncoder()

# %%
df['MS Zoning']=label_encoder.fit_transform(df['MS Zoning'])

# %%
df['MS Zoning']
# Out:
# 1       3
# 2       4
# 3       4
# 4       4
# 5       4
#        ..
# 2925    4
# 2926    4
# 2927    4
# 2928    4
# 2929    4
# Name: MS Zoning, Length: 2617, dtype: int64

# %%
# One-Hot Encoding
OHE = OneHotEncoder()

# %%
Encoded = OHE.fit_transform(df[['Lot Shape']]).toarray()

# %%
# Create a DataFrame for the encoded columns
encoded_df = pd.DataFrame(
    Encoded,
    columns=OHE.get_feature_names_out(['Lot Shape'])

)

# %% [markdown]
# Normalize or scale numerical features

# %%
# Importing StandardScaler
from sklearn.preprocessing import StandardScaler

# %%
# Selecting only the numerical features
numerical_features = df.select_dtypes(include=[np.number])

# %%
# Initialize StandardScaler
scaler = StandardScaler()

# %%
# Fit and transform the numerical features
scaled_numerical = scaler.fit_transform(numerical_features)

# %%
# Convert scaled data back into a DataFrame
scaled_numerical_df = pd.DataFrame(scaled_numerical, columns=numerical_features.columns)

# %%
# Replace the numerical columns in original dataframe with scaled values
# (If you want to keep both original and scaled, make a copy before replacing)
for col in numerical_features.columns:
    df[col] = scaled_numerical_df[col]

# %%
# Check the result
df.head()
# Out:
#       Order       PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area Street  \
# 1 -1.722845 -1.016453    -0.884619  -0.047872      0.771894  1.725223   Pave
# 2 -1.721664 -1.016442    -0.884619  -0.047872      1.428639  0.721852   Pave
# 3 -1.720483 -1.012453     0.036014  -0.047872      0.388792  1.584099   Pave
# 4 -1.719302 -1.012453     0.036014  -0.047872      0.607707  0.340139   Pave
# 5 -1.718121 -1.012336     1.416964  -0.047872     -1.417257 -1.293286   Pave
#
#   Lot Shape Land Contour Utilities  ... Enclosed Porch 3Ssn Porch  \
# 1       Reg          Lvl    AllPub  ...      -0.377350  -0.099128
# 2       IR1          Lvl    AllPub  ...      -0.377350  -0.099128
# 3       Reg          Lvl    AllPub  ...      -0.377350  -0.099128
# 4       IR1          Lvl    AllPub  ...      -0.377350  -0.099128
# 5       IR1          Lvl    AllPub  ...       2.520768  -0.099128
#
#   Screen Porch Pool Area   Misc Val   Mo Sold   Yr Sold  Sale Type  \
# ...

# %%
df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Exter Qual', 'Exter Cond', 'Foundation', 'Heating',
#        'Heating QC', 'Central Air', 'Electrical', '1st Flr SF', '2nd Flr SF',
#        'Low Qual Fin SF', 'Gr Liv Area', 'Full Bath', 'Half Bath',
#        'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd',
#        'Functional', 'Fireplaces', 'Garage Area', 'Paved Drive',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
#        'Screen Porch', 'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold',
#        'Sale Type', 'Sale Condition', 'SalePrice'],
#       dtype='object')

# %%
#Total Square Footage
df['TotalSF'] = df['1st Flr SF'] + df['2nd Flr SF']

# %%
# Total Porch Area
df['TotalPorchSF'] = (df['Open Porch SF'] + df['Enclosed Porch'] +
                     df['3Ssn Porch'] + df['Screen Porch'])

# %%
# Total Bathrooms
df['TotalBathrooms'] = (df['Full Bath'] + df['Half Bath'] )

# %%
# Let's check the new columns added
df.head()
# Out:
#       Order       PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area Street  \
# 1 -1.722845 -1.016453    -0.884619  -0.047872      0.771894  1.725223   Pave
# 2 -1.721664 -1.016442    -0.884619  -0.047872      1.428639  0.721852   Pave
# 3 -1.720483 -1.012453     0.036014  -0.047872      0.388792  1.584099   Pave
# 4 -1.719302 -1.012453     0.036014  -0.047872      0.607707  0.340139   Pave
# 5 -1.718121 -1.012336     1.416964  -0.047872     -1.417257 -1.293286   Pave
#
#   Lot Shape Land Contour Utilities  ... Pool Area   Misc Val   Mo Sold  \
# 1       Reg          Lvl    AllPub  ... -0.033059  26.613937 -0.073726
# 2       IR1          Lvl    AllPub  ... -0.033059  -0.092038 -0.817236
# 3       Reg          Lvl    AllPub  ... -0.033059  -0.092038 -1.188991
# 4       IR1          Lvl    AllPub  ... -0.033059  -0.092038 -0.073726
# 5       IR1          Lvl    AllPub  ... -0.033059  -0.092038 -0.817236
#
#     Yr Sold Sale Type Sale Condition SalePrice   TotalSF  TotalPorchSF  \
# ...

# %% [markdown]
# EDA

# %%
# Select numerical columns
num_cols = df.select_dtypes(include=[np.number]).columns

# %%
# Central Tendency
mean_vals = df[num_cols].mean()
median_vals = df[num_cols].median()
mode_vals = df[num_cols].mode().iloc[0]

# %%
mean_vals
# Out:
# Order             -0.011695
# PID                0.043217
# MS SubClass       -0.001028
# MS Zoning          0.019652
# Lot Frontage       0.013160
# Lot Area           0.003009
# Overall Qual      -0.008250
# Overall Cond      -0.005025
# Year Built        -0.011738
# Year Remod/Add    -0.007749
# 1st Flr SF        -0.004582
# 2nd Flr SF         0.000903
# Low Qual Fin SF    0.009087
# Gr Liv Area       -0.001824
# Full Bath          0.001473
# Half Bath         -0.010736
# Bedroom AbvGr     -0.002294
# Kitchen AbvGr      0.008186
# TotRms AbvGrd     -0.001682
# Fireplaces        -0.004164
# Garage Area        0.000592
# Wood Deck SF       0.006289
# Open Porch SF     -0.010687
# Enclosed Porch     0.007490
# 3Ssn Porch         0.002368
# Screen Porch      -0.010043
# Pool Area         -0.011042
# Misc Val           0.003589
# Mo Sold            0.002540
# Yr Sold            0.019444
# SalePrice         -0.004045
# TotalSF           -0.003679
# TotalPorchSF      -0.010872
# ...

# %%
median_vals
# Out:
# Order             -0.025155
# PID                0.976940
# MS SubClass       -0.194144
# MS Zoning         -0.047872
# Lot Frontage       0.127440
# Lot Area           0.043681
# Overall Qual       0.037293
# Overall Cond      -0.530226
# Year Built         0.025593
# Year Remod/Add     0.363351
# 1st Flr SF        -0.173284
# 2nd Flr SF        -0.784933
# Low Qual Fin SF   -0.097622
# Gr Liv Area       -0.074760
# Full Bath          0.908219
# Half Bath         -0.718178
# Bedroom AbvGr      0.236492
# Kitchen AbvGr     -0.210232
# TotRms AbvGrd     -0.183660
# Fireplaces        -0.869201
# Garage Area        0.069549
# Wood Deck SF      -0.725308
# Open Porch SF     -0.347629
# Enclosed Porch    -0.377350
# 3Ssn Porch        -0.099128
# Screen Porch      -0.277053
# Pool Area         -0.033059
# Misc Val          -0.092038
# Mo Sold           -0.073726
# Yr Sold            0.148658
# SalePrice         -0.193434
# TotalSF           -0.060590
# TotalPorchSF      -0.670238
# ...

# %%
mode_vals
# Out:
# Order             -1.722845
# PID               -1.016713
# MS SubClass       -0.884619
# MS Zoning         -0.047872
# Lot Frontage       0.127440
# Lot Area           0.218068
# Overall Qual      -0.737280
# Overall Cond      -0.530226
# Year Built         1.153479
# Year Remod/Add    -1.595275
# 1st Flr SF        -0.726615
# 2nd Flr SF        -0.784933
# Low Qual Fin SF   -0.097622
# Gr Liv Area       -1.369801
# Full Bath          0.908219
# Half Bath         -0.718178
# Bedroom AbvGr      0.236492
# Kitchen AbvGr     -0.210232
# TotRms AbvGrd     -0.183660
# Fireplaces        -0.869201
# Garage Area       -2.254542
# Wood Deck SF      -0.725308
# Open Porch SF     -0.712256
# Enclosed Porch    -0.377350
# 3Ssn Porch        -0.099128
# Screen Porch      -0.277053
# Pool Area         -0.033059
# Misc Val          -0.092038
# Mo Sold           -0.073726
# Yr Sold           -0.609701
# SalePrice         -0.455297
# TotalSF           -1.511549
# TotalPorchSF      -1.465787
# ...

# %%
# Dispersion
variance_vals = df[num_cols].var()
std_vals = df[num_cols].std()

# %%
variance_vals
# Out:
# Order              0.993534
# PID                1.000101
# MS SubClass        1.011480
# MS Zoning          0.966769
# Lot Frontage       0.993978
# Lot Area           0.990226
# Overall Qual       0.997177
# Overall Cond       0.996501
# Year Built         1.013959
# Year Remod/Add     1.004856
# 1st Flr SF         1.000512
# 2nd Flr SF         1.003430
# Low Qual Fin SF    1.115677
# Gr Liv Area        1.010918
# Full Bath          1.000143
# Half Bath          0.990730
# Bedroom AbvGr      0.995917
# Kitchen AbvGr      1.044364
# TotRms AbvGrd      1.001926
# Fireplaces         0.995837
# Garage Area        1.017987
# Wood Deck SF       1.016577
# Open Porch SF      0.985052
# Enclosed Porch     1.014612
# 3Ssn Porch         1.044006
# Screen Porch       0.977177
# Pool Area          0.591945
# Misc Val           1.074517
# Mo Sold            0.993934
# Yr Sold            0.992516
# SalePrice          1.015695
# TotalSF            1.228479
# TotalPorchSF       3.528328
# ...

# %%
std_vals
# Out:
# Order              0.996762
# PID                1.000051
# MS SubClass        1.005724
# MS Zoning          0.983244
# Lot Frontage       0.996985
# Lot Area           0.995101
# Overall Qual       0.998587
# Overall Cond       0.998249
# Year Built         1.006955
# Year Remod/Add     1.002425
# 1st Flr SF         1.000256
# 2nd Flr SF         1.001714
# Low Qual Fin SF    1.056256
# Gr Liv Area        1.005444
# Full Bath          1.000072
# Half Bath          0.995354
# Bedroom AbvGr      0.997956
# Kitchen AbvGr      1.021941
# TotRms AbvGrd      1.000962
# Fireplaces         0.997916
# Garage Area        1.008953
# Wood Deck SF       1.008255
# Open Porch SF      0.992498
# Enclosed Porch     1.007279
# 3Ssn Porch         1.021766
# Screen Porch       0.988523
# Pool Area          0.769380
# Misc Val           1.036589
# Mo Sold            0.996962
# Yr Sold            0.996251
# SalePrice          1.007817
# TotalSF            1.108368
# TotalPorchSF       1.878384
# ...

# %%
# Display basic statistics
desc_stats = pd.DataFrame({
    'Mean': mean_vals,
    'Median': median_vals,
    'Mode': mode_vals,
    'Variance': variance_vals,
    'Standard Deviation': std_vals
})

display(desc_stats)
# Out:
#                      Mean    Median      Mode  Variance  Standard Deviation
# Order           -0.011695 -0.025155 -1.722845  0.993534            0.996762
# PID              0.043217  0.976940 -1.016713  1.000101            1.000051
# MS SubClass     -0.001028 -0.194144 -0.884619  1.011480            1.005724
# MS Zoning        0.019652 -0.047872 -0.047872  0.966769            0.983244
# Lot Frontage     0.013160  0.127440  0.127440  0.993978            0.996985
# Lot Area         0.003009  0.043681  0.218068  0.990226            0.995101
# Overall Qual    -0.008250  0.037293 -0.737280  0.997177            0.998587
# Overall Cond    -0.005025 -0.530226 -0.530226  0.996501            0.998249
# Year Built      -0.011738  0.025593  1.153479  1.013959            1.006955
# Year Remod/Add  -0.007749  0.363351 -1.595275  1.004856            1.002425
# 1st Flr SF      -0.004582 -0.173284 -0.726615  1.000512            1.000256
# ...

# %% [markdown]
# Visualization:

# %%
#Plot Histograms (Distributions of Numerical Features)
df[num_cols].hist(figsize=(20, 15), bins=30, edgecolor='black', color='purple')
plt.suptitle("Histogram - Distribution of Numerical Features", fontsize=20)
plt.tight_layout()
plt.show()

# %%
#  KDE / Density Plot of SalePrice
plt.figure(figsize=(8, 5))
sns.kdeplot(df['SalePrice'], fill=True, color='teal')
plt.title('PDF (Density Plot) of SalePrice')
plt.xlabel('SalePrice')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Exter Qual', 'Exter Cond', 'Foundation', 'Heating',
#        'Heating QC', 'Central Air', 'Electrical', '1st Flr SF', '2nd Flr SF',
#        'Low Qual Fin SF', 'Gr Liv Area', 'Full Bath', 'Half Bath',
#        'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd',
#        'Functional', 'Fireplaces', 'Garage Area', 'Paved Drive',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
#        'Screen Porch', 'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold',
#        'Sale Type', 'Sale Condition', 'SalePrice', 'TotalSF', 'TotalPorchSF',
# ...

# %%
# 3. 🔍 Pair Plot (Relationships between variables)
# We'll take a few relevant features for simplicity
pair_cols = ['SalePrice', 'Gr Liv Area', 'TotalSF', 'Garage Area', 'Overall Qual']
sns.pairplot(df[pair_cols], diag_kind='kde')
plt.suptitle('Pair Plot - Relationship Between Key Features', y=1.02)
plt.show()

# %%
# 4. 🧊 Correlation Matrix + Heatmap
corr_matrix = df[num_cols].corr()

plt.figure(figsize=(16, 12))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, linewidths=0.5)
plt.title('Heatmap - Correlation Between Numerical Features', fontsize=18)
plt.show()

# %%
#  Scatter Plot: GrLivArea vs SalePrice
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Gr Liv Area', y='SalePrice', hue='Overall Qual', palette='viridis')
plt.title('GrLivArea vs SalePrice Colored by OverallQual')
plt.xlabel('Above Ground Living Area (sq ft)')
plt.ylabel('Sale Price')
plt.legend(title='OverallQual')
plt.grid(True)
plt.show()

# %%
#  Subplots for Histograms
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Histograms of Key Numerical Features', fontsize=16)

for ax, feature in zip(axes.flatten(), num_cols):
    sns.histplot(df[feature], bins=30, kde=True, ax=ax, color='skyblue')
    ax.set_title(f'Distribution of {feature}')
    ax.set_xlabel(feature)
    ax.set_ylabel('Count')
